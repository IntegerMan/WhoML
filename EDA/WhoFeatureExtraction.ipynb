# %% [markdown]
# # Doctor Who Feature Extraction
#
# This notebook seeks to work with the `Merged.csv` file created in [the WhoAggregation Notebook](WhoAggregation.ipynb) to engineer meaningful columns. These values are then saved into `Processed.csv`.

# %%
# Imports
import pandas as pd
import json

# %%
# Load the dataset
df = pd.read_csv('../Data/Merged.csv')

# Drop Junk Columns or columns represented by other columns
df.drop(columns=['Unnamed: 0', 'number', 'episodenbr', 'air_date'], inplace=True)

# Remove % from Share
df['share'] = df['share'].str.replace('%','')

# Remove m from views
df['views'] = df['views'].str.replace('m','')

df = df.sort_values('date')

df.head()
# Out:
#                     title  doctorid  rating  votes  \
# 89                   Rose         9     7.6   6504
# 51   The End of the World         9     7.6   5684
# 143      The Unquiet Dead         9     7.6   5326
# 35       Aliens of London         9     7.0   5116
# 68        World War Three         9     7.1   4943
#
#                                            description  season episode_id  \
# 89   When ordinary shop-worker Rose Tyler meets a m...      27       27-1
# 51   The Doctor takes Rose to the year 5 billion to...      27       27-2
# 143  The Doctor has great expectations for his late...      27       27-3
# 35   The Doctor returns Rose to her own time - well...      27       27-4
# 68   The Slitheen have infiltrated Parliament and h...      27       27-5
#
#     weekday broadcasthour  duration  views share    AI  chart  \
# 89      Sat        7:00pm  00:44:14  10.81  44.8  76.0      7
# 51      Sat        6:59pm  00:44:45   7.97  37.8  76.0     19
# 143     Sat        7:00pm  00:44:50   8.86  37.8  80.0     15
# 35      Sat        7:00pm  00:45:05   7.63  35.7  82.0     18
# 68      Sat        7:01pm  00:40:40   7.98  40.2  81.0     20
#
#                                                   cast  \
# 89   [{"role":"Doctor Who","name":"Christopher Eccl...
# 51   [{"role":"Doctor Who","name":"Christopher Eccl...
# 143  [{"role":"Doctor Who","name":"Christopher Eccl...
# 35   [{"role":"Doctor Who","name":"Christopher Eccl...
# 68   [{"role":"Doctor Who","name":"Christopher Eccl...
#
#                                                   crew summary        date
# 89   [{"role":"Writer","name":"Russell T Davies"},{...     NaN  2005-03-26
# 51   [{"role":"Writer","name":"Russell T Davies"},{...     NaN  2005-04-02
# 143  [{"role":"Writer","name":"Mark Gatiss"},{"role...     NaN  2005-04-09
# 35   [{"role":"Writer","name":"Russell T Davies"},{...     NaN  2005-04-16
# 68   [{"role":"Writer","name":"Russell T Davies"},{...     NaN  2005-04-23

# %%
# Engineer columns for the relevant doctors
df['Has 9'] = df['doctorid'] == 9
df['Has 10'] = df['doctorid'] == 10
df['Has 11'] = df['doctorid'] == 11
df['Has 12'] = df['doctorid'] == 12
df['Has 13'] = df['doctorid'] == 13

# Convert Boolean Columns to Numeric
df.replace({False: 0, True: 1}, inplace=True)

df
# Out:
#                                title  doctorid  rating  votes  \
# 89                              Rose         9     7.6   6504
# 51              The End of the World         9     7.6   5684
# 143                 The Unquiet Dead         9     7.6   5326
# 35                  Aliens of London         9     7.0   5116
# 68                   World War Three         9     7.1   4943
# ..                               ...       ...     ...    ...
# 45                          Kerblam!        13     6.4   3954
# 85                  The Witchfinders        13     5.9   3635
# 52                 It Takes You Away        13     6.4   3404
# 144  The Battle of Ranskoor Av Kolos        13     5.5   2949
# 2                         Resolution        13     6.0   2690
#
#                                            description  season episode_id  \
# 89   When ordinary shop-worker Rose Tyler meets a m...      27       27-1
# 51   The Doctor takes Rose to the year 5 billion to...      27       27-2
# 143  The Doctor has great expectations for his late...      27       27-3
# 35   The Doctor returns Rose to her own time - well...      27       27-4
# 68   The Slitheen have infiltrated Parliament and h...      27       27-5
# ..                                                 ...     ...        ...
# 45   A mysterious message arrives in a package addr...      37       37-7
# 85   Arriving in 17th Century Lancashire, the TARDI...      37       37-8
# 52   On the edge of a Norwegian fjord, in the prese...      37       37-9
# 144  Answering nine separate distress calls, the Do...      37      37-10
# 2    As the New Year begins, a terrifying evil is s...      37      37-11
#
#     weekday broadcasthour  duration  ... chart  \
# 89      Sat        7:00pm  00:44:14  ...     7
# 51      Sat        6:59pm  00:44:45  ...    19
# 143     Sat        7:00pm  00:44:50  ...    15
# 35      Sat        7:00pm  00:45:05  ...    18
# 68      Sat        7:01pm  00:40:40  ...    20
# ..      ...           ...       ...  ...   ...
# 45      Sun        6:30pm  00:48:50  ...     9
# 85      Sun        6:30pm  00:46:31  ...    17
# 52      Sun        6:31pm  00:49:11  ...    22
# 144     Sun        6:25pm  00:49:40  ...    18
# 2       Tue        7:00pm  01:00:00  ...    14
#
#                                                   cast  \
# 89   [{"role":"Doctor Who","name":"Christopher Eccl...
# 51   [{"role":"Doctor Who","name":"Christopher Eccl...
# 143  [{"role":"Doctor Who","name":"Christopher Eccl...
# 35   [{"role":"Doctor Who","name":"Christopher Eccl...
# 68   [{"role":"Doctor Who","name":"Christopher Eccl...
# ..                                                 ...
# 45   [{"role":"The Doctor","name":"Jodie Whittaker"...
# 85   [{"role":"The Doctor","name":"Jodie Whittaker"...
# 52   [{"role":"The Doctor","name":"Jodie Whittaker"...
# 144  [{"role":"The Doctor","name":"Jodie Whittaker"...
# 2    [{"role":"The Doctor","name":"Jodie Whittaker"...
#
#                                                   crew  \
# 89   [{"role":"Writer","name":"Russell T Davies"},{...
# 51   [{"role":"Writer","name":"Russell T Davies"},{...
# 143  [{"role":"Writer","name":"Mark Gatiss"},{"role...
# 35   [{"role":"Writer","name":"Russell T Davies"},{...
# 68   [{"role":"Writer","name":"Russell T Davies"},{...
# ..                                                 ...
# 45   [{"role":"Writer","name":"Pete McTighe"},{"rol...
# 85   [{"role":"Writer","name":"Joy Wilkinson"},{"ro...
# 52   [{"role":"Writer","name":"Ed Hime"},{"role":"D...
# 144  [{"role":"Writer","name":"Chris Chibnall"},{"r...
# 2    [{"role":"Writer","name":"Chris Chibnall"},{"r...
#
#                                                summary        date Has 9  \
# 89                                                 NaN  2005-03-26     1
# 51                                                 NaN  2005-04-02     1
# 143                                                NaN  2005-04-09     1
# 35                                                 NaN  2005-04-16     1
# 68                                                 NaN  2005-04-23     1
# ..                                                 ...         ...   ...
# 45   “Delivery for the Doctor!” \n\n \n\nA mysterio...  2018-11-18     0
# 85   The Doctor, Ryan, Graham and Yaz arrive in 17t...  2018-11-25     0
# 52   On the edge of a Norwegian fjord, in the prese...  2018-12-02     0
# 144  On the planet of Ranskoor Av Kolos, lies the r...  2018-12-09     0
# 2                                                  NaN  2019-01-01     0
#
#     Has 10 Has 11  Has 12  Has 13
# 89       0      0       0       0
# 51       0      0       0       0
# 143      0      0       0       0
# 35       0      0       0       0
# 68       0      0       0       0
# ..     ...    ...     ...     ...
# 45       0      0       0       1
# 85       0      0       0       1
# 52       0      0       0       1
# 144      0      0       0       1
# 2        0      0       0       1
#
# [146 rows x 23 columns]

# %%
# Determine which notable characters / monsters are in the episode
noteable_characters = [
    'Rose Tyler', 
    'Mickey Smith', 
    'Jackie Tyler', 
    'Cyberman',
    'Dalek',
    'Commander Strax'
    'Captain Jack Harkness',
    'Sarah Jane Smith',
    'Ood',
    'Donna Noble',
    'Martha Jones',
    'Judoon',
    'Amy Pond',
    'Rory',
    'River Song',
    'Clara',
    'Weeping Angel',
    'The Silent',
    'Madame Kovarian',
    'Madame Vastra',
    'Winston Churchill',
    'Sophie',
    'Jenny Flint',
    'The War Doctor',
    'Danny Pink',
    'Bill',
    'Osgood',
    'The Master',
    'Kate Lethbridge-Stewart',
    'Zygon',
    'Sontaran',
    'Nardole',
    'Yasmin Khan',
    'Graham O\'Brien',
    'Ryan Sinclair',
    'Grace',
    'Winston Churchill'
]

def extract_cast_info(row):

    # Load information about cast
    data = row['cast']
    arr = json.loads(data)
    for role in arr:
        roleName = role['role']

        # Clean up names
        if roleName.startswith('Dalek'):
            roleName = 'Dalek'
        if roleName.startswith('Cyber'):
            roleName = 'Cyberman'
        if roleName == 'Rory Williams':
            roleName = 'Rory'
        if roleName == 'Angel Bob':
            roleName = 'Weeping Angel'
        if roleName.startswith('Judoon'):
            roleName = 'Judoon'
        if roleName == 'Silent':
            roleName = 'The Silent'
        if roleName == 'Emperor Winston Churchill' or roleName == 'Churchill':
            roleName = 'Winston Churchill'

        # Add a column for the character if we care about them
        if roleName in noteable_characters:
            row['Has ' + roleName] = 1

    # Return the row with new characters
    return row

df = df.apply(extract_cast_info, axis=1)
df.head()
# Out:
#        AI  Has 10  Has 11  Has 12  Has 13  Has 9  Has Amy Pond  Has Bill  \
# 89   76.0       0       0       0       0      1           NaN       NaN
# 51   76.0       0       0       0       0      1           NaN       NaN
# 143  80.0       0       0       0       0      1           NaN       NaN
# 35   82.0       0       0       0       0      1           NaN       NaN
# 68   81.0       0       0       0       0      1           NaN       NaN
#
#      Has Clara  Has Cyberman  ...  duration  episode_id  rating  season  \
# 89         NaN           NaN  ...  00:44:14        27-1     7.6      27
# 51         NaN           NaN  ...  00:44:45        27-2     7.6      27
# 143        NaN           NaN  ...  00:44:50        27-3     7.6      27
# 35         NaN           NaN  ...  00:45:05        27-4     7.0      27
# 68         NaN           NaN  ...  00:40:40        27-5     7.1      27
#
#      share  summary                 title  views  votes  weekday
# 89    44.8      NaN                  Rose  10.81   6504      Sat
# 51    37.8      NaN  The End of the World   7.97   5684      Sat
# 143   37.8      NaN      The Unquiet Dead   8.86   5326      Sat
# 35    35.7      NaN      Aliens of London   7.63   5116      Sat
# 68    40.2      NaN       World War Three   7.98   4943      Sat
#
# [5 rows x 57 columns]

# %%
# Determine key information about crew - director and writer, mostly
def extract_crew_info(row):

    data = row['crew']

    arr = json.loads(data)
    for pair in arr:
        role = pair['role']
        name = pair['name']

        # Note: This code does not adequately handle multiple writers / producers / directors
        if role == 'Writer':
            row['Writer'] = name
        elif role == 'Producer':
            row['Producer'] = name
        elif role == 'Director':
            row['Director'] = name
        elif role == 'Incidental Music' or role == 'Music' or role == 'Composer':
            row['Music'] = name

    return row

df = df.apply(extract_crew_info, axis=1)
df.head()
# Out:
#        AI    Director  Has 10  Has 11  Has 12  Has 13  Has 9  Has Amy Pond  \
# 89   76.0  Keith Boak       0       0       0       0      1           NaN
# 51   76.0   Euros Lyn       0       0       0       0      1           NaN
# 143  80.0   Euros Lyn       0       0       0       0      1           NaN
# 35   82.0  Keith Boak       0       0       0       0      1           NaN
# 68   81.0  Keith Boak       0       0       0       0      1           NaN
#
#      Has Bill  Has Clara  ...  duration  episode_id  rating  season  share  \
# 89        NaN        NaN  ...  00:44:14        27-1     7.6      27   44.8
# 51        NaN        NaN  ...  00:44:45        27-2     7.6      27   37.8
# 143       NaN        NaN  ...  00:44:50        27-3     7.6      27   37.8
# 35        NaN        NaN  ...  00:45:05        27-4     7.0      27   35.7
# 68        NaN        NaN  ...  00:40:40        27-5     7.1      27   40.2
#
#      summary                 title  views  votes  weekday
# 89       NaN                  Rose  10.81   6504      Sat
# 51       NaN  The End of the World   7.97   5684      Sat
# 143      NaN      The Unquiet Dead   8.86   5326      Sat
# 35       NaN      Aliens of London   7.63   5116      Sat
# 68       NaN       World War Three   7.98   4943      Sat
#
# [5 rows x 61 columns]

# %%
# Fix some missing values in our source data
df.loc[df['title'].eq('The Power of Three'), ['Director']] = 'Douglas Mackinnon'
df.loc[df['title'].eq('Closing Time'), ['Producer']] = 'Denise Paul'

df.head()
# Out:
#        AI    Director  Has 10  Has 11  Has 12  Has 13  Has 9  Has Amy Pond  \
# 89   76.0  Keith Boak       0       0       0       0      1           NaN
# 51   76.0   Euros Lyn       0       0       0       0      1           NaN
# 143  80.0   Euros Lyn       0       0       0       0      1           NaN
# 35   82.0  Keith Boak       0       0       0       0      1           NaN
# 68   81.0  Keith Boak       0       0       0       0      1           NaN
#
#      Has Bill  Has Clara  ...  duration  episode_id  rating  season  share  \
# 89        NaN        NaN  ...  00:44:14        27-1     7.6      27   44.8
# 51        NaN        NaN  ...  00:44:45        27-2     7.6      27   37.8
# 143       NaN        NaN  ...  00:44:50        27-3     7.6      27   37.8
# 35        NaN        NaN  ...  00:45:05        27-4     7.0      27   35.7
# 68        NaN        NaN  ...  00:40:40        27-5     7.1      27   40.2
#
#      summary                 title  views  votes  weekday
# 89       NaN                  Rose  10.81   6504      Sat
# 51       NaN  The End of the World   7.97   5684      Sat
# 143      NaN      The Unquiet Dead   8.86   5326      Sat
# 35       NaN      Aliens of London   7.63   5116      Sat
# 68       NaN       World War Three   7.98   4943      Sat
#
# [5 rows x 61 columns]

# %%
# Move NaN columns to use 0's instead (helps summarization)
df['Director'] = df['Director'].fillna('Other')
df['Writer'] = df['Writer'].fillna('Other')
df['Producer'] = df['Producer'].fillna('Other')
df['Music'] = df['Music'].fillna('Other')
df = df.fillna(0)

# Drop unnecessary columns now that feature extraction is over
df.set_index('episode_id', inplace=True)
df.drop(columns=['crew', 'cast', 'summary','AI','broadcasthour','chart','description','duration','share','views', 'votes', 'weekday'], inplace=True)

# Translate the season number to be relative to "New Who"
df['season'] = df['season'] - 26

df.head()
# Out:
#               Director  Has 10  Has 11  Has 12  Has 13  Has 9  Has Amy Pond  \
# episode_id
# 27-1        Keith Boak       0       0       0       0      1           0.0
# 27-2         Euros Lyn       0       0       0       0      1           0.0
# 27-3         Euros Lyn       0       0       0       0      1           0.0
# 27-4        Keith Boak       0       0       0       0      1           0.0
# 27-5        Keith Boak       0       0       0       0      1           0.0
#
#             Has Bill  Has Clara  Has Cyberman  ...  Has Yasmin Khan  \
# episode_id                                     ...
# 27-1             0.0        0.0           0.0  ...              0.0
# 27-2             0.0        0.0           0.0  ...              0.0
# 27-3             0.0        0.0           0.0  ...              0.0
# 27-4             0.0        0.0           0.0  ...              0.0
# 27-5             0.0        0.0           0.0  ...              0.0
#
#             Has Zygon        Music        Producer            Writer  \
# episode_id
# 27-1              0.0  Murray Gold  Phil Collinson  Russell T Davies
# 27-2              0.0  Murray Gold  Phil Collinson  Russell T Davies
# 27-3              0.0  Murray Gold  Phil Collinson       Mark Gatiss
# 27-4              0.0  Murray Gold  Phil Collinson  Russell T Davies
# 27-5              0.0  Murray Gold  Phil Collinson  Russell T Davies
#
#                   date  doctorid  rating  season                 title
# episode_id
# 27-1        2005-03-26         9     7.6       1                  Rose
# 27-2        2005-04-02         9     7.6       1  The End of the World
# 27-3        2005-04-09         9     7.6       1      The Unquiet Dead
# 27-4        2005-04-16         9     7.0       1      Aliens of London
# 27-5        2005-04-23         9     7.1       1       World War Three
#
# [5 rows x 48 columns]

# %%
# Descriptive Statistics
df.describe(include='all')
# Out:
#              Director      Has 10      Has 11      Has 12      Has 13  \
# count             146  146.000000  146.000000  146.000000  146.000000
# unique             49         NaN         NaN         NaN         NaN
# top     Graeme Harper         NaN         NaN         NaN         NaN
# freq               11         NaN         NaN         NaN         NaN
# mean              NaN    0.287671    0.287671    0.260274    0.075342
# std               NaN    0.454235    0.454235    0.440294    0.264852
# min               NaN    0.000000    0.000000    0.000000    0.000000
# 25%               NaN    0.000000    0.000000    0.000000    0.000000
# 50%               NaN    0.000000    0.000000    0.000000    0.000000
# 75%               NaN    1.000000    1.000000    1.000000    0.000000
# max               NaN    1.000000    1.000000    1.000000    1.000000
#
#              Has 9  Has Amy Pond    Has Bill   Has Clara  Has Cyberman  ...  \
# count   146.000000    146.000000  146.000000  146.000000    146.000000  ...
# unique         NaN           NaN         NaN         NaN           NaN  ...
# top            NaN           NaN         NaN         NaN           NaN  ...
# freq           NaN           NaN         NaN         NaN           NaN  ...
# mean      0.089041      0.226027    0.089041    0.226027      0.075342  ...
# std       0.285783      0.419697    0.285783    0.419697      0.264852  ...
# min       0.000000      0.000000    0.000000    0.000000      0.000000  ...
# 25%       0.000000      0.000000    0.000000    0.000000      0.000000  ...
# 50%       0.000000      0.000000    0.000000    0.000000      0.000000  ...
# 75%       0.000000      0.000000    0.000000    0.000000      0.000000  ...
# max       1.000000      1.000000    1.000000    1.000000      1.000000  ...
#
#         Has Yasmin Khan   Has Zygon        Music        Producer  \
# count        146.000000  146.000000          146             146
# unique              NaN         NaN            2              13
# top                 NaN         NaN  Murray Gold  Phil Collinson
# freq                NaN         NaN          135              48
# mean           0.075342    0.013699          NaN             NaN
# std            0.264852    0.116637          NaN             NaN
# min            0.000000    0.000000          NaN             NaN
# 25%            0.000000    0.000000          NaN             NaN
# 50%            0.000000    0.000000          NaN             NaN
# 75%            0.000000    0.000000          NaN             NaN
# max            1.000000    1.000000          NaN             NaN
#
#                Writer        date    doctorid      rating      season  title
# count             146         146  146.000000  146.000000  146.000000    146
# unique             31         146         NaN         NaN         NaN    146
# top     Steven Moffat  2005-03-26         NaN         NaN         NaN   Rose
# freq               44           1         NaN         NaN         NaN      1
# mean              NaN         NaN   10.945205    7.911644    5.869863    NaN
# std               NaN         NaN    1.100350    0.943984    3.112298    NaN
# min               NaN         NaN    9.000000    5.200000    1.000000    NaN
# 25%               NaN         NaN   10.000000    7.300000    3.000000    NaN
# 50%               NaN         NaN   11.000000    7.900000    6.000000    NaN
# 75%               NaN         NaN   12.000000    8.700000    8.750000    NaN
# max               NaN         NaN   13.000000    9.800000   11.000000    NaN
#
# [11 rows x 48 columns]

# %%
# Serialize to File for further analysis
df.to_csv('../Data/Processed.csv')
